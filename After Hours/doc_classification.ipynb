# %%
# 3rd party imports
import pandas as pd
import numpy as np
import spacy
# sklearn imports
from sklearn.ensemble import RandomForestClassifier

# %%
# Create file path
FILE_PATH = r"C:\Users\Nocx\Downloads\reviews_Tools_and_Home_Improvement_5.json"

# %%
# Load into DataFrame
DF = pd.read_json(FILE_PATH, lines=True)

# %%
# view head
DF.head()
# Out:
#          asin   helpful  overall  \
# 0  104800001X    [0, 1]        5
# 1  104800001X    [0, 0]        5
# 2  104800001X    [0, 0]        5
# 3  104800001X    [0, 0]        5
# 4  104800001X  [23, 25]        5
#
#                                           reviewText   reviewTime  \
# 0  I hate it when my shirt collars, not otherwise...  01 29, 2014
# 1  These little magnets are really powerful for t...  05 31, 2013
# 2  I wanted something this small to mount on the ...  03 13, 2013
# 3  I use these to magnetize my Warhammer 40K mini...  06 16, 2013
# 4  They are soo freaking annoying!!  Why?! You sp...   08 9, 2013
#
#        reviewerID                   reviewerName  \
# 0   A4IL0CLL27Q33                     D. Brennan
# 1  A3Q5W5E7TDVLJF                      funnyc130
# 2   A37KNOJXE2FU6                Joseph Yonke II
# 3  A3U4AFML9SZPWK  Leith Tussing "I like tacos."
# 4  A36Y7X194VWVKA                        Mark D.
#
#                                              summary  unixReviewTime
# 0                 Perfect for collar stay management      1390953600
# 1                                               Neat      1369958400
# 2                                Very small and thin      1363132800
# 3                            Excellent hobby magnets      1371340800
# 4  They're annoying... which is why they get five...      1376006400

# %%
# Set columns to all lowercase for ease
DF.columns = [x.lower() for x in DF.columns.values]

# %%
# Check out one of the reviews
import random

DF.iloc[random.randint(0,137000)]['reviewtext']
# Out:
# 'I am one guy who refuses to buy inferior drill bits. These Bosch bits are not the best but this set available on Amazon is one of the better deals you will find. Use these bits properly without abusing them they will last a long time.'

# %%
# Don't need all of these columns. Drop the unimportant ones.
DF = DF[['overall', 'reviewtext']].copy()

# %%
# Check class balance
DF['overall'].value_counts()
# Out:
# 5    85266
# 4    28336
# 3    10769
# 1     5143
# 2     4962
# Name: overall, dtype: int64

# %%
# Seems pretty imbalanced...
print("5/5:", round((85266/134476), 3)*100)
print("4/5:", round((28336/134476), 3)*100)
print("3/5:", round((10769/134476), 3)*100)
print("2/5:", round((5143/134476), 3)*100)
print("1/5:", round((4962/134476), 3)*100)
# Out:
# 5/5: 63.4
# 4/5: 21.099999999999998
# 3/5: 8.0
# 2/5: 3.8
# 1/5: 3.6999999999999997

# %%
# To fix, let's change the problem
print("5/5:", round((85266/134476), 3)*100,"%")
print("Not a 5:", round(((28336+10769+5143+4962)/134476), 3)*100,"%")
# Out:
# 5/5: 63.4 %
# Not a 5: 36.6 %

# %%
# Create target column
DF['is_5'] = [1 if x == 5 else 0 for x in DF['overall']]

# %% [markdown]
# ## Setting up a test case

# %%
# Get a random document
T1 = DF.iloc[5823:5825]

# %%
T1['reviewtext']
# Out:
# 5823    Well, now I remember why I don't like this 'cl...
# 5824    I bought this and returned it. It jammed every...
# Name: reviewtext, dtype: object

# %% [markdown]
# ### Tokenize this text

# %%
nlp = spacy.load('en_core_web_lg')

# %%
I = 5823
STOPWORDS = [' ', '  ']

for doc in nlp.pipe(T1['reviewtext']):
    print(f"Doc {I}: Is 5? {DF.iloc[I]['is_5']}")
    I += 1
    
    for token in doc:
        if (not token.is_punct) & \
        (not token.is_stop) & \
        (not token.is_digit) & \
        (str(token) not in SPACES):
            print(str(token.lemma_).lower())
print('\n')
# Out:
# Doc 5823: Is 5? 0
# remember
# like
# classic
# stapler
# look
# feel
# like
# heavy
# stapler
# grow
# heavy
# take
# lot
# pressure
# squeeze
# handle
# staple
# fabric
# batting
# wood
# headboard
# misfire
# staple
# need
# tap
# hammer
# good
# old
# stapler
# previous
# project
# stapler
# squeeze
# handle
# like
# better
# maybe
# misfire
# couple
# time
# stapler
# stick
# past
# heavy
# cumbersome
# use
# like
# load
# staple
# slide
# work
# yes
# fun
# use
# price
# picky
# probably
# fine
# Doc 5824: Is 5? 0
# buy
# return
# jam
# staple
# christmas
# light
# minute
# job
# turn
# hour
# clearing
# jam
# staple
# desirable
# go
# great
# review
# money
# quality
# product
# thing
# cheap
# usa
# reason
# company
# hire
# low
# bidder

# %%
# # Create new documents from processed tokens
# DOCS = list()

# for doc in nlp.pipe(DF['reviewtext']):
#     # make an empty list for tokens
#     t = list()
#     for token in doc:
#         # Filter the tokens
#         if (not token.is_punct) &\
#         (not token.is_stop) &\
#         (not token.is_digit) &\
#         (str(token) not in STOPWORDS):
#             t.append(str(token.lemma_).lower())
#     DOCS.append(' '.join(t))
    
# ######################
# #    INTERRUPTED     #
# ######################

# %%
# Finished 1999 in the time it ran. Let's just use the first 1000
DFS = DF.loc[:999, :].copy()

# %%
# Create cleaned column
DFS['cleaned'] = docs[:1000]

# %%
DFS
# Out:
#      overall                                         reviewtext  is_5  \
# 0          5  I hate it when my shirt collars, not otherwise...     1
# 1          5  These little magnets are really powerful for t...     1
# 2          5  I wanted something this small to mount on the ...     1
# 3          5  I use these to magnetize my Warhammer 40K mini...     1
# 4          5  They are soo freaking annoying!!  Why?! You sp...     1
# 5          5  am using for 40k models, they are a great size...     1
# 6          5  The color pictures and exploded diagrams are a...     1
# 7          3  Good simple projects to start you using the Kr...     0
# 8          5  These are projects that people can do with pre...     1
# 9          5  If you have a pocket holl jig then this book i...     1
# 10         4  This has nice projects even someone just start...     0
# 11         4  Has some good information in it.  The projects...     0
# 12         2  Thought this book would be chock full of great...     0
# 13         5  This is a great system for drilling perfect po...     1
# 14         5  If you're new to pocket joinery, this is a gre...     1
# 15         4  This book is not biased toward any particular ...     0
# 16         5  This is a great book for anyone interested in ...     1
# 17         3  From reading all the glowing reviews here, I t...     0
# 18         4  When I recently purchased the Kreg system, I w...     0
# 19         5  Some useful projects to use with my new pocket...     1
# 20         4  I bought this so I could make a few projects w...     0
# 21         5                    Awesome to light an entire room     1
# 22         5  Update: I purchased this light in January of 2...     1
# 23         5  I have a Kindle and love it. I haven't found a...     1
# 24         5  I bought this for my wife so she could read bo...     1
# 25         5  Perfect light to read with or for the grill.  ...     1
# 26         2  This light is useless for reading in bed next ...     0
# 27         5  I originally bought this for my wife so she co...     1
# 28         5  There isn't a whole lot to say about a book li...     1
# 29         5  I bought this light for my wife not myself.  S...     1
# ..       ...                                                ...   ...
# 970        5  I've used mine about a dozen times.  Trimming ...     1
# 971        5  If you are in the business,  then you know wha...     1
# 972        4  It's strange how a tool I never knew existed w...     0
# 973        5  I own a few other Bosch tools and they all wor...     1
# 974        4  Pros:- "Flush Cutting" means the blade literal...     0
# 975        5  The title of this review says it all.  These b...     1
# 976        5  When I use this item what would be the best wa...     1
# 977        5  T shank blades work will with my new Makita ji...     1
# 978        5  The best jigsaw blades I know. Cut 2x4s square...     1
# 979        5  I bought these for my B&D Pira&ntilde;a trim s...     1
# 980        5  If you need to make some coarse wood cuts then...     1
# 981        5  They do cut fairly clean but not so much on th...     1
# 982        4  Buy these blades and not cheap blades - you ge...     0
# 983        5  I put these in my cheap black and decker jigsa...     1
# 984        5  These are wicked blades. Combine this with a g...     1
# 985        5  These blades work well and were exactly what I...     1
# 986        5  These blades are great.  I put them through th...     1
# 987        5  The Bosch T234X Progressor wood blades set is ...     1
# 988        5  These blades are very sharp the cuts that use ...     1
# 989        5  As always, a great product at a great price.  ...     1
# 990        5  These are fast cutting and do a good job if yo...     1
# 991        5  These blades are sharp and cut very smoothly. ...     1
# 992        5  Progressor Wood Blades. I wanted some blades t...     1
# 993        4  I have only used one of these blades a couple ...     0
# 994        5  I have a terrible black & Decker Jig that want...     1
# 995        5  Bosch makes the best jig saw blades in my mind...     1
# 996        5  I'm crazy about these blades, blades that perf...     1
# 997        5  These blades cut efficiently and stay sharp wi...     1
# 998        5  These blades work great and make a nice smooth...     1
# 999        5  I didn't know what a great tool my Milwaukee s...     1
#
#                                                cleaned
# 0    hate shirt collar secure place button end weir...
# 1    little magnet powerful size secret compartment...
# 2    want small mount filagree wood piece cut mount...
# 3    use magnetize warhammer k miniature allow swap...
# 4    soo freaking annoying spend time da*n near bre...
# 5    40k model great size add jet pack use ork spac...
# 6    color picture explode diagram outstanding intr...
# 7    good simple project start kreg tool joint book...
# 8    project people pretty basic wood tool nice tab...
# 9        pocket holl jig book nice project book simple
# 10   nice project start find want simple instructio...
# 11         good information project include book level
# 12   think book chock great project use kreg jig in...
# 13   great system drill perfect pocket joint time e...
# 14   new pocket joinery great book instruction insp...
# 15   book biased particular brand pocket hole jig s...
# 16   great book interested get foot wet pocket join...
# 17   read glowing review think book well plan stuff...
# 18   recently purchase kreg system look reference s...
# 19   useful project use new pocket hole tool look f...
# 20   buy project kreg pocket jig thing kreg get boo...
# 21                           awesome light entire room
# 22   update purchase light january pleased month no...
# 23   kindle love find need particular situation rea...
# 24   buy wife read book poorly light house work gre...
# 25   perfect light read grill set medium light brig...
# 26   light useless read bed bulb light entire room ...
# 27   originally buy wife read bed use laptop clip e...
# 28   lot book light work like take aaa battery chea...
# 29   buy light wife hard time sleep light head thin...
# ..                                                 ...
# 970  dozen time trim door molding instal floor tile...
# 971  business know pain set dewalt miter see punch ...
# 972  strange tool know exist drift awareness week d...
# 973  bosch tool work flawlessly great handsaw kit b...
# 974  pros:- flush cutting mean blade literally slid...
# 975  title review say blade separate set tooth cut ...
# 976  use item good way describe fundamentaly useful...
# 977  t shank blade work new makita jig see chatter ...
# 978  good jigsaw blade know cut 2x4s square blade m...
# 979  buy b&d pira&ntilde;a trim see wish tad longer...
# 980                           need coarse wood cut job
# 981  cut fairly clean scroll cut want cut fast awes...
# 982  buy blade cheap blade pay power accessory like...
# 983  cheap black decker jigsaw amazed smoothness cu...
# 984  wicked blade combine good jigsaw tool try diff...
# 985  blade work exactly need cut laminate flooring ...
# 986  blade great pace right away clamp 1/2&#34 pine...
# 987  bosch t234x progressor wood blade set set blad...
# 988  blade sharp cut use minute take second think s...
# 989  great product great price purchase amazon year...
# 990  fast cut good job rough work want fine work bo...
# 991  blade sharp cut smoothly corded porter cable c...
# 992  progressor wood blades want blade go job easy ...
# 993  blade couple time purchasing lot saw use thing...
# 994  terrible black decker jig want turn left const...
# 995  bosch make good jig saw blade mind particular ...
# 996  crazy blade blade perform exactly promise cut ...
# 997  blade cut efficiently stay sharp use thick bre...
# 998  blade work great nice smooth straight cut nice...
# 999  know great tool milwaukee saber see buy blade ...
#
# [1000 rows x 4 columns]

# %%
# Feature / target split
X = DFS['cleaned']
y = DFS['is_5']

# %%
# Do a train / test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
X_train.shape,y_train.shape, X_test.shape,y_test.shape
# Out:
# ((750,), (750,), (250,), (250,))

# %%
# Vectorize
def embed(docs):
    return [nlp(doc).vector for doc in docs]

# Instantiate model
classifier = RandomForestClassifier(n_estimators=100, random_state=107,
                                   max_depth=7)
# Fit the model on training data
classifier.fit(embed(X_train), y_train)

# Get predictions
pred = classifier.predict(embed(X_test))

# %%
from collections import Counter
Counter(pred)[1] / 250
# Out:
# 0.82

# %%
classifier.score(embed(X_test), y_test)
# Out:
# 0.688
